# %%
import pandas as pd

# %%
data=[10,20,30,40]
s=pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data=pd.Series([10,20,30,40,50],index=["a", "b", "c", "d","e"],name="numbers")
data
df=pd.DataFrame(data)
df
# Out:
#    numbers
# a       10
# b       20
# c       30
# d       40
# e       50

# %%
data[3]
# Out:
# C:\Users\na499\AppData\Local\Temp\ipykernel_10812\977688468.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data[3]
# np.int64(40)

# %%
data1={
     "Name": ["Anish", "Rahul", "Sneha"],
    "Age": [21, 22, 20],
    "Marks": [85, 90, 88]
}
data1
# Out:
# {'Name': ['Anish', 'Rahul', 'Sneha'],
#  'Age': [21, 22, 20],
#  'Marks': [85, 90, 88]}

# %%
df=pd.DataFrame(data1)
df
# Out:
#     Name  Age  Marks
# 0  Anish   21     85
# 1  Rahul   22     90
# 2  Sneha   20     88

# %%
df=pd.read_csv("data.csv")
# pd.read_excel("filename with extinsion")
# pd.read_json("filename with extinsion")
df
# Out:
#     fruit   color  price  WEIGHT
# 0   mango  orange  500.0       3
# 1   mango  orange  500.0       3
# 2  banana  yellow  100.0       1
# 3   apple     red  600.0       5
# 4  orange  orange  100.0       2
# 5  grapes   green    NaN       1
# 6  sapota   brown  300.0      10

# %%
df.head(3)
# Out:
#     fruit   color  price  WEIGHT
# 0   mango  orange  500.0       3
# 1   mango  orange  500.0       3
# 2  banana  yellow  100.0       1

# %%
print(df.tail(13))
print("\n")
print(df.tail(3))
# Out:
#     fruit   color  price  WEIGHT
# 0   mango  orange  500.0       3
# 1   mango  orange  500.0       3
# 2  banana  yellow  100.0       1
# 3   apple     red  600.0       5
# 4  orange  orange  100.0       2
# 5  grapes   green    NaN       1
# 6  sapota   brown  300.0      10
#
#
#     fruit   color  price  WEIGHT
# 4  orange  orange  100.0       2
# 5  grapes   green    NaN       1
# 6  sapota   brown  300.0      10

# %%
df.sample(3)
# Out:
#     fruit   color  price  WEIGHT
# 0   mango  orange  500.0       3
# 6  sapota   brown  300.0      10
# 3   apple     red  600.0       5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fruit   7 non-null      object
#  1   color   7 non-null      object
#  2   price   6 non-null      float64
#  3   WEIGHT  7 non-null      int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 356.0+ bytes

# %%
print(df)
print("\n")
print(df.describe())
# Out:
#     fruit   color  price  WEIGHT
# 0   mango  orange  500.0       3
# 1   mango  orange  500.0       3
# 2  banana  yellow  100.0       1
# 3   apple     red  600.0       5
# 4  orange  orange  100.0       2
# 5  grapes   green    NaN       1
# 6  sapota   brown  300.0      10
#
#
#             price     WEIGHT
# count    6.000000   7.000000
# mean   350.000000   3.571429
# std    216.794834   3.154739
# min    100.000000   1.000000
# 25%    150.000000   1.500000
# 50%    400.000000   3.000000
# 75%    500.000000   4.000000
# max    600.000000  10.000000

# %%
df.shape
# Out:
# (7, 4)

# %%
df.columns
# Out:
# Index(['fruit', 'color', 'price', 'WEIGHT'], dtype='object')

# %%
df.dtypes
# Out:
# fruit      object
# color      object
# price     float64
# WEIGHT      int64
# dtype: object

# %%
df
# Out:
#     fruit   color  price  WEIGHT
# 0   mango  orange  500.0       3
# 1   mango  orange  500.0       3
# 2  banana  yellow  100.0       1
# 3   apple     red  600.0       5
# 4  orange  orange  100.0       2
# 5  grapes   green    NaN       1
# 6  sapota   brown  300.0      10

# %%
print(df["color"])
print("\n")
print(df["color"].shape)
# Out:
# 0    orange
# 1    orange
# 2    yellow
# 3       red
# 4    orange
# 5     green
# 6     brown
# Name: color, dtype: object
#
#
# (7,)

# %%
df[["color","fruit","WEIGHT"]]
# Out:
#     color   fruit  WEIGHT
# 0  orange   mango       3
# 1  orange   mango       3
# 2  yellow  banana       1
# 3     red   apple       5
# 4  orange  orange       2
# 5   green  grapes       1
# 6   brown  sapota      10

# %%
df.loc[0:2]
# Out:
#     fruit   color  price  WEIGHT
# 0   mango  orange  500.0       3
# 1   mango  orange  500.0       3
# 2  banana  yellow  100.0       1

# %%
df.iloc[0:2]
# Out:
#    fruit   color  price  WEIGHT
# 0  mango  orange  500.0       3
# 1  mango  orange  500.0       3

# %%
df
# Out:
#     fruit   color  price  WEIGHT
# 0   mango  orange  500.0       3
# 1   mango  orange  500.0       3
# 2  banana  yellow  100.0       1
# 3   apple     red  600.0       5
# 4  orange  orange  100.0       2
# 5  grapes   green    NaN       1
# 6  sapota   brown  300.0      10

# %%
df[df["price"]>100]
# Out:
#     fruit   color  price  WEIGHT
# 0   mango  orange  500.0       3
# 1   mango  orange  500.0       3
# 3   apple     red  600.0       5
# 6  sapota   brown  300.0      10

# %%
df[df["WEIGHT"] < 10 ]
# Out:
#     fruit   color  price  WEIGHT
# 0   mango  orange  500.0       3
# 1   mango  orange  500.0       3
# 2  banana  yellow  100.0       1
# 3   apple     red  600.0       5
# 4  orange  orange  100.0       2
# 5  grapes   green    NaN       1

# %%
df[(df["WEIGHT"] <5) & (df["price"] > 300)]
# Out:
#    fruit   color  price  WEIGHT
# 0  mango  orange  500.0       3
# 1  mango  orange  500.0       3

# %%
df[(df["WEIGHT"] < 10) & (df["price"] == 100)]
# Out:
#     fruit   color  price  WEIGHT
# 2  banana  yellow  100.0       1
# 4  orange  orange  100.0       2

# %%
df["place"]=["karnataka","mumbai","kashmir","karnataka","kerala","delhi"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 df["place"]=["karnataka","mumbai","kashmir","karnataka","kerala","delhi"]
#
# File c:\Users\na499\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File c:\Users\na499\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)   4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
# ...

# %%
df
# Out:
#     fruit   color  price  WEIGHT      place
# 0   mango  orange  500.0       3  karnataka
# 1  banana  yellow  100.0       1     mumbai
# 2   apple     red  600.0       5    kashmir
# 3  orange  orange  100.0       2  karnataka
# 4  grapes   green    NaN       1     kerala
# 5  sapota   brown  300.0      10      delhi

# %%
df["WEIGHT"] = df["WEIGHT"] + 1

# %%
df
# Out:
#     fruit   color  price  WEIGHT      place
# 0   mango  orange  500.0       4  karnataka
# 1  banana  yellow  100.0       2     mumbai
# 2   apple     red  600.0       6    kashmir
# 3  orange  orange  100.0       3  karnataka
# 4  grapes   green    NaN       2     kerala
# 5  sapota   brown  300.0      11      delhi

# %%
df.drop("WEIGHT",axis=1)
# Out:
#     fruit   color  price      place
# 0   mango  orange  500.0  karnataka
# 1  banana  yellow  100.0     mumbai
# 2   apple     red  600.0    kashmir
# 3  orange  orange  100.0  karnataka
# 4  grapes   green    NaN     kerala
# 5  sapota   brown  300.0      delhi

# %%
df.drop("WEIGHT",axis=1,inplace=True)
df
# Out:
#     fruit   color  price      place
# 0   mango  orange  500.0  karnataka
# 1  banana  yellow  100.0     mumbai
# 2   apple     red  600.0    kashmir
# 3  orange  orange  100.0  karnataka
# 4  grapes   green    NaN     kerala
# 5  sapota   brown  300.0      delhi

# %%
df.drop(2,axis=0)
# Out:
#     fruit   color  price      place
# 0   mango  orange  500.0  karnataka
# 1  banana  yellow  100.0     mumbai
# 3  orange  orange  100.0  karnataka
# 4  grapes   green    NaN     kerala
# 5  sapota   brown  300.0      delhi

# %%
df.drop(2,axis=0,inplace=True)
df
# Out:
#     fruit   color  price      place
# 0   mango  orange  500.0  karnataka
# 1  banana  yellow  100.0     mumbai
# 3  orange  orange  100.0  karnataka
# 4  grapes   green    NaN     kerala
# 5  sapota   brown  300.0      delhi

# %%
df.isnull()
# Out:
#    fruit  color  price  place
# 0  False  False  False  False
# 1  False  False  False  False
# 3  False  False  False  False
# 4  False  False   True  False
# 5  False  False  False  False

# %%
df.isna()
# Out:
#    fruit  color  price  place
# 0  False  False  False  False
# 1  False  False  False  False
# 3  False  False  False  False
# 4  False  False   True  False
# 5  False  False  False  False

# %%
df.isnull().value_counts()
# Out:
# fruit  color  price  place
# False  False  False  False    4
#               True   False    1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# fruit    0
# color    0
# price    1
# place    0
# dtype: int64

# %%
df.fillna(df["price"].mean(),inplace=True)

# %%
df.dropna()
# Out:
#     fruit   color  price      place
# 0   mango  orange  500.0  karnataka
# 1  banana  yellow  100.0     mumbai
# 3  orange  orange  100.0  karnataka
# 4  grapes   green  250.0     kerala
# 5  sapota   brown  300.0      delhi

# %%
df
# Out:
#     fruit   color  price      place
# 0   mango  orange  500.0  karnataka
# 1  banana  yellow  100.0     mumbai
# 3  orange  orange  100.0  karnataka
# 4  grapes   green  250.0     kerala
# 5  sapota   brown  300.0      delhi

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     fruit   color  price      place
# 0   mango  orange  500.0  karnataka
# 1  banana  yellow  100.0     mumbai
# 3  orange  orange  100.0  karnataka
# 4  grapes   green  250.0     kerala
# 5  sapota   brown  300.0      delhi

# %%
df.sort_values("price",ascending=True) #assending order of price
# Out:
#     fruit   color  price      place
# 1  banana  yellow  100.0     mumbai
# 3  orange  orange  100.0  karnataka
# 4  grapes   green  250.0     kerala
# 5  sapota   brown  300.0      delhi
# 0   mango  orange  500.0  karnataka

# %%
df.sort_values("fruit",ascending=False) #descending order of alphabet
# Out:
#     fruit   color  price      place
# 5  sapota   brown  300.0      delhi
# 3  orange  orange  100.0  karnataka
# 0   mango  orange  500.0  karnataka
# 4  grapes   green  250.0     kerala
# 1  banana  yellow  100.0     mumbai

# %%
df
# Out:
#     fruit   color  price      place
# 0   mango  orange  500.0  karnataka
# 1  banana  yellow  100.0     mumbai
# 3  orange  orange  100.0  karnataka
# 4  grapes   green  250.0     kerala
# 5  sapota   brown  300.0      delhi

# %%
df.rename(columns={"color":"fruit color"},inplace=True)

# %%
df
# Out:
#     fruit fruit color  price      place
# 0   mango      orange  500.0  karnataka
# 1  banana      yellow  100.0     mumbai
# 3  orange      orange  100.0  karnataka
# 4  grapes       green  250.0     kerala
# 5  sapota       brown  300.0      delhi

# %%
df["price"] = df["price"].apply(lambda x: x + 1)

# %%
df["price"]
# Out:
# 0    501.0
# 1    101.0
# 3    101.0
# 4    251.0
# 5    301.0
# Name: price, dtype: float64

# %%
df
# Out:
#     fruit fruit color  price      place
# 0   mango      orange  501.0  karnataka
# 1  banana      yellow  101.0     mumbai
# 3  orange      orange  101.0  karnataka
# 4  grapes       green  251.0     kerala
# 5  sapota       brown  301.0      delhi

# %%
df1 = pd.DataFrame({
    "ID": [1,2,3],
    "Name": ["A","B","C"]
})

df2 = pd.DataFrame({
    "ID": [1,2,4],
    "Marks": [90,85,88]
})

# %%
df.shape
# Out:
# (5, 4)

# %%
df1.shape
# Out:
# (3, 2)

# %%
df2.shape
# Out:
# (3, 2)

# %%
pd.concat([df1, df])
# Out:
#     ID Name   fruit fruit color  price      place
# 0  1.0    A     NaN         NaN    NaN        NaN
# 1  2.0    B     NaN         NaN    NaN        NaN
# 2  3.0    C     NaN         NaN    NaN        NaN
# 0  NaN  NaN   mango      orange  501.0  karnataka
# 1  NaN  NaN  banana      yellow  101.0     mumbai
# 3  NaN  NaN  orange      orange  101.0  karnataka
# 4  NaN  NaN  grapes       green  251.0     kerala
# 5  NaN  NaN  sapota       brown  301.0      delhi

# %%
pd.merge(df1,df2)
# Out:
#    ID Name  Marks
# 0   1    A     90
# 1   2    B     85

# %%
df["color"].value_counts()
# Out:
# color
# orange    3
# yellow    1
# red       1
# green     1
# brown     1
# Name: count, dtype: int64

# %%
df
# Out:
#     fruit   color  price  WEIGHT
# 0   mango  orange  500.0       3
# 1   mango  orange  500.0       3
# 2  banana  yellow  100.0       1
# 3   apple     red  600.0       5
# 4  orange  orange  100.0       2
# 5  grapes   green    NaN       1
# 6  sapota   brown  300.0      10

# %%
df.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     fruit   color  price  WEIGHT
# 0   mango  orange  500.0       3
# 2  banana  yellow  100.0       1
# 3   apple     red  600.0       5
# 4  orange  orange  100.0       2
# 5  grapes   green    NaN       1
# 6  sapota   brown  300.0      10

# %%
df["color"]=df["color"].str.upper()

# %%
df
# Out:
#     fruit   color  price  WEIGHT
# 0   mango  ORANGE  500.0       3
# 2  banana  YELLOW  100.0       1
# 3   apple     RED  600.0       5
# 4  orange  ORANGE  100.0       2
# 5  grapes   GREEN    NaN       1
# 6  sapota   BROWN  300.0      10

# %%
datedata={
    "name":["anish","rohit","mahesh"],"date":["2025-05-13","2001-07-20","2018-12-26"]
}
df4=pd.DataFrame(datedata)
df4
# Out:
#      name        date
# 0   anish  2025-05-13
# 1   rohit  2001-07-20
# 2  mahesh  2018-12-26

# %%
df4["Date"]=pd.to_datetime(df4["date"]) #changes the attribute from string to date 
df4
# Out:
#      name       date       Date
# 0   anish 2025-05-13 2025-05-13
# 1   rohit 2001-07-20 2001-07-20
# 2  mahesh 2018-12-26 2018-12-26

# %%
df4["year"]=df4["Date"].dt.year
df4
# Out:
#      name       date       Date  year
# 0   anish 2025-05-13 2025-05-13  2025
# 1   rohit 2001-07-20 2001-07-20  2001
# 2  mahesh 2018-12-26 2018-12-26  2018

# %%
df4["Month"]=df4["Date"].dt.month
df4
# Out:
#      name       date       Date  year  Month
# 0   anish 2025-05-13 2025-05-13  2025      5
# 1   rohit 2001-07-20 2001-07-20  2001      7
# 2  mahesh 2018-12-26 2018-12-26  2018     12

# %%
df.fillna(df["price"].mean(),inplace=True)
df
# Out:
#     fruit   color  price  WEIGHT
# 0   mango  orange  500.0       3
# 1   mango  orange  500.0       3
# 2  banana  yellow  100.0       1
# 3   apple     red  600.0       5
# 4  orange  orange  100.0       2
# 5  grapes   green  350.0       1
# 6  sapota   brown  300.0      10

# %%
# df.to_csv("newdata.csv",index=False)
# df.to_excel("newdata.xlsx",index=False)
# df.to_json("newdata.json",index=False)
